# %% [markdown]
# # Imports

# %%
# !pip install pydicom
# Out:
# Requirement already satisfied: pydicom in /usr/local/lib/python3.10/dist-packages (2.4.3)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from keras.utils import to_categorical
import os
import re
import cv2
import pydicom
import nibabel as nib
from glob import glob
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
import tensorflow as tf
from keras import backend as K
import math
tf.config.run_functions_eagerly(True)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Custom Metrics

# %%
def dice_coef(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)

    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    smooth = 0.0001
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_coef_multilabel(y_true, y_pred, numLabels = 6):
    dice = 0
    weights = [0.17649986,  7.78453571, 41.53978194, 65.20657672, 96.75504125,  6.40743063]
    for index in range(numLabels):
        dice += dice_coef(y_true[:,:,index], y_pred[:,:,index]) * weights[index]
    return dice/np.sum(weights)

def dice_coef_multilabelloss(y_true, y_pred):
    return 1 - dice_coef_multilabel(y_true, y_pred)

def weightedLoss(originalLossFunc, weightsList):

    def lossFunc(true, pred):
        true = K.cast(true, K.floatx())
        pred = K.cast(pred, K.floatx())

        axis = -1 #if channels last
          #axis=  1 #if channels first


          #argmax returns the index of the element with the greatest value
          #done in the class axis, it returns the class index
        classSelectors = K.argmax(true, axis=axis)
              #if your loss is sparse, use only true as classSelectors

          #considering weights are ordered by class, for each class
          #true(1) if the class index is equal to the weight index
          #weightsList = tf.cast(weightsList, tf.int64)
        classSelectors = [K.equal(tf.cast(i, tf.int64), tf.cast(classSelectors, tf.int64)) for i in range(len(weightsList))]

          #casting boolean to float for calculations
          #each tensor in the list contains 1 where ground true class is equal to its index
          #if you sum all these, you will get a tensor full of ones.
        classSelectors = [K.cast(x, K.floatx()) for x in classSelectors]

          #for each of the selections above, multiply their respective weight
        weights = [sel * w for sel,w in zip(classSelectors, weightsList)]

          #sums all the selections
          #result is a tensor with the respective weight for each element in predictions
        weightMultiplier = weights[0]
        for i in range(1, len(weights)):
            weightMultiplier = weightMultiplier + weights[i]


          #make sure your originalLossFunc only collapses the class axis
          #you need the other axes intact to multiply the weights tensor
        loss = originalLossFunc(true,pred)
        loss = loss * weightMultiplier

        return loss
    return lossFunc

# %% [markdown]
# # U-Net Implementation

# %%
def double_conv_block(x, n_filters):
    # Conv2D then ReLU activation
    x = tf.keras.layers.Conv2D(n_filters, 3, padding = "same", activation = "relu", kernel_initializer = "he_normal")(x)
   # Conv2D then ReLU activation
    x = tf.keras.layers.Conv2D(n_filters, 3, padding = "same", activation = "relu", kernel_initializer = "he_normal")(x)
    return x

def downsample_block(x, n_filters):
    f = double_conv_block(x, n_filters)
    p = tf.keras.layers.MaxPool2D(2)(f)
    p = tf.keras.layers.Dropout(0.3)(p)
    return f, p

def upsample_block(x, conv_features, n_filters):
   # upsample
    x = tf.keras.layers.Conv2DTranspose(n_filters, 3, 2, padding="same")(x)
   # concatenate
    x = tf.keras.layers.concatenate([x, conv_features])
   # dropout
    x = tf.keras.layers.Dropout(0.3)(x)
   # Conv2D twice with ReLU activation
    x = double_conv_block(x, n_filters)
    return x


def build_unet_model():
    # inputs
    units = 128
    inputs = tf.keras.layers.Input(shape=(units,units,1))
   # encoder: contracting path - downsample
   # 1 - downsample
    f1, p1 = downsample_block(inputs, units/4)
   # 2 - downsample
    f2, p2 = downsample_block(p1, units/2)
   # 3 - downsample
    f3, p3 = downsample_block(p2, units*1)
   # 4 - downsample
    f4, p4 = downsample_block(p3, units*2)
   # 5 - bottleneck
    bottleneck = double_conv_block(p4, units*4)
   # decoder: expanding path - upsample
   # 6 - upsample
    u6 = upsample_block(bottleneck, f4, units*2)
   # 7 - upsample
    u7 = upsample_block(u6, f3, units*1)
   # 8 - upsample
    u8 = upsample_block(u7, f2, units/2)
   # 9 - upsample
    u9 = upsample_block(u8, f1, units/4)
   # outputs
    outputs = tf.keras.layers.Conv2D(6, 1, padding="same", activation = "sigmoid")(u9)
   # unet model with Keras Functional API
    unet_model = tf.keras.Model(inputs, outputs, name="U-Net")

    return unet_model

# %%
class_weights = [0.17649986,  7.78453571, 41.53978194, 65.20657672, 96.75504125,  6.40743063]

model = build_unet_model()
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss=weightedLoss(tf.keras.losses.categorical_crossentropy, class_weights), metrics=[dice_coef_multilabel, tf.keras.metrics.MeanIoU(num_classes=6), "accuracy"])

# %% [markdown]
# # Model summary

# %%
model.summary()
# Out:
# Model: "U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 1)]        0         []
#
#  conv2d (Conv2D)             (None, 128, 128, 32)         320       ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 32)         9248      ['conv2d[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 64, 64, 32)           0         ['conv2d_1[0][0]']
#  D)
#
#  dropout (Dropout)           (None, 64, 64, 32)           0         ['max_pooling2d[0][0]']
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 64)           18496     ['dropout[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 64, 64, 64)           36928     ['conv2d_2[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 32, 32, 64)           0         ['conv2d_3[0][0]']
#  g2D)
#
#  dropout_1 (Dropout)         (None, 32, 32, 64)           0         ['max_pooling2d_1[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 32, 32, 128)          73856     ['dropout_1[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 32, 32, 128)          147584    ['conv2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 16, 16, 128)          0         ['conv2d_5[0][0]']
#  g2D)
#
#  dropout_2 (Dropout)         (None, 16, 16, 128)          0         ['max_pooling2d_2[0][0]']
#
#  conv2d_6 (Conv2D)           (None, 16, 16, 256)          295168    ['dropout_2[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 16, 16, 256)          590080    ['conv2d_6[0][0]']
#
#  max_pooling2d_3 (MaxPoolin  (None, 8, 8, 256)            0         ['conv2d_7[0][0]']
#  g2D)
#
#  dropout_3 (Dropout)         (None, 8, 8, 256)            0         ['max_pooling2d_3[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 8, 8, 512)            1180160   ['dropout_3[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 8, 8, 512)            2359808   ['conv2d_8[0][0]']
#
#  conv2d_transpose (Conv2DTr  (None, 16, 16, 256)          1179904   ['conv2d_9[0][0]']
#  anspose)
#
#  concatenate (Concatenate)   (None, 16, 16, 512)          0         ['conv2d_transpose[0][0]',
#                                                                      'conv2d_7[0][0]']
#
#  dropout_4 (Dropout)         (None, 16, 16, 512)          0         ['concatenate[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 16, 16, 256)          1179904   ['dropout_4[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 16, 16, 256)          590080    ['conv2d_10[0][0]']
#
#  conv2d_transpose_1 (Conv2D  (None, 32, 32, 128)          295040    ['conv2d_11[0][0]']
#  Transpose)
#
#  concatenate_1 (Concatenate  (None, 32, 32, 256)          0         ['conv2d_transpose_1[0][0]',
#  )                                                                   'conv2d_5[0][0]']
#
#  dropout_5 (Dropout)         (None, 32, 32, 256)          0         ['concatenate_1[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 32, 32, 128)          295040    ['dropout_5[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 32, 32, 128)          147584    ['conv2d_12[0][0]']
#
#  conv2d_transpose_2 (Conv2D  (None, 64, 64, 64)           73792     ['conv2d_13[0][0]']
#  Transpose)
#
#  concatenate_2 (Concatenate  (None, 64, 64, 128)          0         ['conv2d_transpose_2[0][0]',
#  )                                                                   'conv2d_3[0][0]']
#
#  dropout_6 (Dropout)         (None, 64, 64, 128)          0         ['concatenate_2[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 64, 64, 64)           73792     ['dropout_6[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 64, 64, 64)           36928     ['conv2d_14[0][0]']
#
#  conv2d_transpose_3 (Conv2D  (None, 128, 128, 32)         18464     ['conv2d_15[0][0]']
#  Transpose)
#
#  concatenate_3 (Concatenate  (None, 128, 128, 64)         0         ['conv2d_transpose_3[0][0]',
#  )                                                                   'conv2d_1[0][0]']
#
#  dropout_7 (Dropout)         (None, 128, 128, 64)         0         ['concatenate_3[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 128, 128, 32)         18464     ['dropout_7[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 128, 128, 32)         9248      ['conv2d_16[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 128, 128, 6)          198       ['conv2d_17[0][0]']
#
# ==================================================================================================
# Total params: 8630086 (32.92 MB)
# Trainable params: 8630086 (32.92 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %% [markdown]
# # TRAINING

# %% [markdown]
# ### DataGenerator

# %%
class DataGenerator(tf.keras.utils.Sequence):

    def __init__(self, X_set: np.array, y_set: np.array, num_classes: int, batch_size: int) -> None:
        """_Initialization of data generator_

        Parameters
        ----------
        X_set : np.array
            _Set of images_
        y_set : _np.array_
            _Set of masks_
        num_classes : _int_
            _Number of classes_
        batch_size : _int_
            _Size of the batch taken from X_set and y_set_
        """
        self.x, self.y = X_set, y_set
        self.classes = num_classes
        self.batch_size = batch_size

    def __len__(self):
        return math.ceil(len(self.x) / self.batch_size)

    def __getitem__(self, index):
        """_Get item method for each epoch in training
            and computes categorical values for
            segmentation maks_

        Parameters
        ----------
        index : _int_
            _Integer utilized to return the batches_

        Returns
        -------
        _np.array_
            _Returns the batch from X_set and categorical btach from y_set_
        """
        batch_x = self.x[index * self.batch_size:(index + 1) * self.batch_size]
        batch_y = self.y[index * self.batch_size:(index + 1) * self.batch_size]

        train_masks_cat = to_categorical(batch_y, num_classes=self.classes)
        batch_y_categorical = train_masks_cat.reshape((batch_y.shape[0], batch_y.shape[1], batch_y.shape[2], self.classes))

        return batch_x, batch_y_categorical

# %% [markdown]
# ### Data

# %%
with open(f'/content/drive/MyDrive/RSNA_Abdominal_Trauma_Segmentations/Data/X_y_segmentations_data_0.npy', 'rb') as f:
        X = np.load(f, allow_pickle = True)
        y = np.load(f, allow_pickle = True)

# %%
# Generate random indices for sampling
indices = np.arange(len(X))
np.random.shuffle(indices)
num_samples = 1000
# Select the first num_samples indices
selected_indices = indices[:num_samples]

# Use the selected indices to extract samples from X and Y
X_test = X[selected_indices]
Y_test = y[selected_indices]

print(X_test.shape, Y_test.shape)
# Out:
# (1000, 128, 128, 1) (1000, 128, 128, 1)

# %%
data_generator = DataGenerator(X, y, 6, 64)
data_generator_test = DataGenerator(X_test, Y_test, 6, 64)

# %%
history = model.fit(data_generator,
                    validation_data=data_generator_test,
                    verbose=1,
                    epochs=65,
                    shuffle=False)
# Out:
# Epoch 1/65
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/structured_function.py:265: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
# 248/248 [==============================] - 149s 526ms/step - loss: 1.6095 - dice_coef_multilabel: 0.4511 - mean_io_u: 0.4167 - accuracy: 0.4922 - val_loss: 1.4933 - val_dice_coef_multilabel: 0.5546 - val_mean_io_u: 0.4167 - val_accuracy: 0.5718
# Epoch 2/65
# 248/248 [==============================] - 118s 476ms/step - loss: 1.5063 - dice_coef_multilabel: 0.5415 - mean_io_u: 0.4189 - accuracy: 0.5984 - val_loss: 1.4744 - val_dice_coef_multilabel: 0.5730 - val_mean_io_u: 0.4167 - val_accuracy: 0.6940
# Epoch 3/65
# 248/248 [==============================] - 117s 473ms/step - loss: 1.4058 - dice_coef_multilabel: 0.5418 - mean_io_u: 0.4167 - accuracy: 0.5844 - val_loss: 1.3702 - val_dice_coef_multilabel: 0.5622 - val_mean_io_u: 0.4167 - val_accuracy: 0.6387
# Epoch 4/65
# 248/248 [==============================] - 119s 478ms/step - loss: 1.3759 - dice_coef_multilabel: 0.5553 - mean_io_u: 0.4167 - accuracy: 0.6272 - val_loss: 1.3308 - val_dice_coef_multilabel: 0.5733 - val_mean_io_u: 0.4167 - val_accuracy: 0.6737
# Epoch 5/65
# 248/248 [==============================] - 117s 470ms/step - loss: 1.3105 - dice_coef_multilabel: 0.5672 - mean_io_u: 0.4167 - accuracy: 0.6568 - val_loss: 1.2763 - val_dice_coef_multilabel: 0.5799 - val_mean_io_u: 0.4167 - val_accuracy: 0.6740
# Epoch 6/65
# 248/248 [==============================] - 116s 466ms/step - loss: 1.2777 - dice_coef_multilabel: 0.5726 - mean_io_u: 0.4167 - accuracy: 0.6647 - val_loss: 1.2373 - val_dice_coef_multilabel: 0.5845 - val_mean_io_u: 0.4167 - val_accuracy: 0.6724
# Epoch 7/65
# 248/248 [==============================] - 116s 467ms/step - loss: 1.2468 - dice_coef_multilabel: 0.5777 - mean_io_u: 0.4167 - accuracy: 0.6717 - val_loss: 1.2120 - val_dice_coef_multilabel: 0.5890 - val_mean_io_u: 0.4167 - val_accuracy: 0.6756
# Epoch 8/65
# 248/248 [==============================] - 116s 466ms/step - loss: 1.2192 - dice_coef_multilabel: 0.5837 - mean_io_u: 0.4167 - accuracy: 0.6828 - val_loss: 1.1872 - val_dice_coef_multilabel: 0.5932 - val_mean_io_u: 0.4167 - val_accuracy: 0.6826
# Epoch 9/65
# 248/248 [==============================] - 115s 465ms/step - loss: 1.1943 - dice_coef_multilabel: 0.5876 - mean_io_u: 0.4167 - accuracy: 0.6876 - val_loss: 1.1741 - val_dice_coef_multilabel: 0.5965 - val_mean_io_u: 0.4167 - val_accuracy: 0.6836
# Epoch 10/65
# 248/248 [==============================] - 116s 467ms/step - loss: 1.1571 - dice_coef_multilabel: 0.5932 - mean_io_u: 0.4167 - accuracy: 0.6984 - val_loss: 1.1611 - val_dice_coef_multilabel: 0.5982 - val_mean_io_u: 0.4167 - val_accuracy: 0.6823
# Epoch 11/65
# 248/248 [==============================] - 115s 466ms/step - loss: 1.1413 - dice_coef_multilabel: 0.5964 - mean_io_u: 0.4167 - accuracy: 0.7040 - val_loss: 1.1464 - val_dice_coef_multilabel: 0.5999 - val_mean_io_u: 0.4167 - val_accuracy: 0.6827
# Epoch 12/65
# 248/248 [==============================] - 116s 466ms/step - loss: 1.1208 - dice_coef_multilabel: 0.5994 - mean_io_u: 0.4167 - accuracy: 0.7124 - val_loss: 1.1254 - val_dice_coef_multilabel: 0.6019 - val_mean_io_u: 0.4167 - val_accuracy: 0.6906
# Epoch 13/65
# 248/248 [==============================] - 115s 465ms/step - loss: 1.1038 - dice_coef_multilabel: 0.6043 - mean_io_u: 0.4167 - accuracy: 0.7214 - val_loss: 1.1094 - val_dice_coef_multilabel: 0.6039 - val_mean_io_u: 0.4167 - val_accuracy: 0.7003
# Epoch 14/65
# 248/248 [==============================] - 115s 464ms/step - loss: 1.0884 - dice_coef_multilabel: 0.6078 - mean_io_u: 0.4167 - accuracy: 0.7283 - val_loss: 1.0914 - val_dice_coef_multilabel: 0.6084 - val_mean_io_u: 0.4167 - val_accuracy: 0.7112
# Epoch 15/65
# 248/248 [==============================] - 117s 472ms/step - loss: 1.0746 - dice_coef_multilabel: 0.6125 - mean_io_u: 0.4167 - accuracy: 0.7310 - val_loss: 1.0745 - val_dice_coef_multilabel: 0.6117 - val_mean_io_u: 0.4167 - val_accuracy: 0.7193
# Epoch 16/65
# 248/248 [==============================] - 115s 463ms/step - loss: 1.0626 - dice_coef_multilabel: 0.6141 - mean_io_u: 0.4167 - accuracy: 0.7343 - val_loss: 1.0609 - val_dice_coef_multilabel: 0.6133 - val_mean_io_u: 0.4167 - val_accuracy: 0.7210
# Epoch 17/65
# 248/248 [==============================] - 115s 464ms/step - loss: 1.0556 - dice_coef_multilabel: 0.6144 - mean_io_u: 0.4167 - accuracy: 0.7337 - val_loss: 1.0484 - val_dice_coef_multilabel: 0.6118 - val_mean_io_u: 0.4167 - val_accuracy: 0.7207
# Epoch 18/65
# 248/248 [==============================] - 115s 464ms/step - loss: 1.0425 - dice_coef_multilabel: 0.6170 - mean_io_u: 0.4167 - accuracy: 0.7376 - val_loss: 1.0352 - val_dice_coef_multilabel: 0.6184 - val_mean_io_u: 0.4167 - val_accuracy: 0.7256
# Epoch 19/65
# 248/248 [==============================] - 117s 471ms/step - loss: 1.0355 - dice_coef_multilabel: 0.6187 - mean_io_u: 0.4167 - accuracy: 0.7381 - val_loss: 1.0242 - val_dice_coef_multilabel: 0.6191 - val_mean_io_u: 0.4167 - val_accuracy: 0.7270
# Epoch 20/65
# 248/248 [==============================] - 115s 464ms/step - loss: 1.0284 - dice_coef_multilabel: 0.6195 - mean_io_u: 0.4167 - accuracy: 0.7399 - val_loss: 1.0173 - val_dice_coef_multilabel: 0.6194 - val_mean_io_u: 0.4167 - val_accuracy: 0.7296
# Epoch 21/65
# 248/248 [==============================] - 117s 474ms/step - loss: 1.0220 - dice_coef_multilabel: 0.6196 - mean_io_u: 0.4167 - accuracy: 0.7401 - val_loss: 1.0092 - val_dice_coef_multilabel: 0.6177 - val_mean_io_u: 0.4167 - val_accuracy: 0.7323
# Epoch 22/65
# 248/248 [==============================] - 115s 464ms/step - loss: 1.0130 - dice_coef_multilabel: 0.6187 - mean_io_u: 0.4167 - accuracy: 0.7440 - val_loss: 1.0012 - val_dice_coef_multilabel: 0.6207 - val_mean_io_u: 0.4167 - val_accuracy: 0.7324
# Epoch 23/65
# 248/248 [==============================] - 117s 472ms/step - loss: 1.0053 - dice_coef_multilabel: 0.6211 - mean_io_u: 0.4167 - accuracy: 0.7456 - val_loss: 0.9918 - val_dice_coef_multilabel: 0.6177 - val_mean_io_u: 0.4167 - val_accuracy: 0.7318
# Epoch 24/65
# 248/248 [==============================] - 115s 465ms/step - loss: 0.9996 - dice_coef_multilabel: 0.6195 - mean_io_u: 0.4168 - accuracy: 0.7473 - val_loss: 0.9842 - val_dice_coef_multilabel: 0.6182 - val_mean_io_u: 0.4167 - val_accuracy: 0.7383
# Epoch 25/65
# 248/248 [==============================] - 117s 471ms/step - loss: 0.9936 - dice_coef_multilabel: 0.6221 - mean_io_u: 0.4168 - accuracy: 0.7506 - val_loss: 0.9790 - val_dice_coef_multilabel: 0.6223 - val_mean_io_u: 0.4167 - val_accuracy: 0.7334
# Epoch 26/65
# 248/248 [==============================] - 115s 464ms/step - loss: 0.9874 - dice_coef_multilabel: 0.6260 - mean_io_u: 0.4169 - accuracy: 0.7505 - val_loss: 0.9739 - val_dice_coef_multilabel: 0.6243 - val_mean_io_u: 0.4167 - val_accuracy: 0.7399
# Epoch 27/65
# 248/248 [==============================] - 115s 465ms/step - loss: 0.9813 - dice_coef_multilabel: 0.6246 - mean_io_u: 0.4168 - accuracy: 0.7544 - val_loss: 0.9686 - val_dice_coef_multilabel: 0.6268 - val_mean_io_u: 0.4167 - val_accuracy: 0.7421
# Epoch 28/65
# 248/248 [==============================] - 115s 465ms/step - loss: 0.9772 - dice_coef_multilabel: 0.6277 - mean_io_u: 0.4169 - accuracy: 0.7562 - val_loss: 0.9661 - val_dice_coef_multilabel: 0.6246 - val_mean_io_u: 0.4167 - val_accuracy: 0.7371
# Epoch 29/65
# 248/248 [==============================] - 117s 473ms/step - loss: 0.9726 - dice_coef_multilabel: 0.6279 - mean_io_u: 0.4169 - accuracy: 0.7562 - val_loss: 0.9612 - val_dice_coef_multilabel: 0.6272 - val_mean_io_u: 0.4167 - val_accuracy: 0.7403
# Epoch 30/65
# 248/248 [==============================] - 115s 463ms/step - loss: 0.9694 - dice_coef_multilabel: 0.6286 - mean_io_u: 0.4169 - accuracy: 0.7576 - val_loss: 0.9580 - val_dice_coef_multilabel: 0.6267 - val_mean_io_u: 0.4167 - val_accuracy: 0.7393
# Epoch 31/65
# 248/248 [==============================] - 115s 464ms/step - loss: 0.9673 - dice_coef_multilabel: 0.6286 - mean_io_u: 0.4169 - accuracy: 0.7585 - val_loss: 0.9549 - val_dice_coef_multilabel: 0.6286 - val_mean_io_u: 0.4167 - val_accuracy: 0.7406
# Epoch 32/65
# 248/248 [==============================] - 115s 463ms/step - loss: 0.9618 - dice_coef_multilabel: 0.6289 - mean_io_u: 0.4169 - accuracy: 0.7604 - val_loss: 0.9511 - val_dice_coef_multilabel: 0.6292 - val_mean_io_u: 0.4167 - val_accuracy: 0.7427
# Epoch 33/65
# 248/248 [==============================] - 115s 463ms/step - loss: 0.9563 - dice_coef_multilabel: 0.6312 - mean_io_u: 0.4169 - accuracy: 0.7608 - val_loss: 0.9476 - val_dice_coef_multilabel: 0.6321 - val_mean_io_u: 0.4167 - val_accuracy: 0.7498
# Epoch 34/65
# 248/248 [==============================] - 115s 463ms/step - loss: 0.9519 - dice_coef_multilabel: 0.6318 - mean_io_u: 0.4169 - accuracy: 0.7626 - val_loss: 0.9444 - val_dice_coef_multilabel: 0.6315 - val_mean_io_u: 0.4167 - val_accuracy: 0.7514
# Epoch 35/65
# 248/248 [==============================] - 117s 471ms/step - loss: 0.9483 - dice_coef_multilabel: 0.6341 - mean_io_u: 0.4169 - accuracy: 0.7639 - val_loss: 0.9415 - val_dice_coef_multilabel: 0.6308 - val_mean_io_u: 0.4167 - val_accuracy: 0.7575
# Epoch 36/65
# 248/248 [==============================] - 118s 474ms/step - loss: 0.9435 - dice_coef_multilabel: 0.6340 - mean_io_u: 0.4169 - accuracy: 0.7678 - val_loss: 0.9404 - val_dice_coef_multilabel: 0.6294 - val_mean_io_u: 0.4167 - val_accuracy: 0.7544
# Epoch 37/65
# 248/248 [==============================] - 117s 472ms/step - loss: 0.9420 - dice_coef_multilabel: 0.6389 - mean_io_u: 0.4168 - accuracy: 0.7650 - val_loss: 0.9372 - val_dice_coef_multilabel: 0.6274 - val_mean_io_u: 0.4167 - val_accuracy: 0.7551
# Epoch 38/65
# 248/248 [==============================] - 115s 463ms/step - loss: 1.0373 - dice_coef_multilabel: 0.6262 - mean_io_u: 0.4170 - accuracy: 0.7622 - val_loss: 0.9792 - val_dice_coef_multilabel: 0.6203 - val_mean_io_u: 0.4167 - val_accuracy: 0.7545
# Epoch 39/65
# 248/248 [==============================] - 114s 460ms/step - loss: 0.9499 - dice_coef_multilabel: 0.6252 - mean_io_u: 0.4168 - accuracy: 0.7642 - val_loss: 0.9420 - val_dice_coef_multilabel: 0.6279 - val_mean_io_u: 0.4167 - val_accuracy: 0.7620
# Epoch 40/65
# 248/248 [==============================] - 115s 463ms/step - loss: 0.9376 - dice_coef_multilabel: 0.6290 - mean_io_u: 0.4168 - accuracy: 0.7703 - val_loss: 0.9372 - val_dice_coef_multilabel: 0.6306 - val_mean_io_u: 0.4167 - val_accuracy: 0.7635
# Epoch 41/65
# 248/248 [==============================] - 115s 463ms/step - loss: 0.9339 - dice_coef_multilabel: 0.6312 - mean_io_u: 0.4168 - accuracy: 0.7703 - val_loss: 0.9325 - val_dice_coef_multilabel: 0.6315 - val_mean_io_u: 0.4167 - val_accuracy: 0.7620
# Epoch 42/65
# 248/248 [==============================] - 115s 462ms/step - loss: 0.9298 - dice_coef_multilabel: 0.6313 - mean_io_u: 0.4168 - accuracy: 0.7705 - val_loss: 0.9300 - val_dice_coef_multilabel: 0.6237 - val_mean_io_u: 0.4167 - val_accuracy: 0.7601
# Epoch 43/65
# 248/248 [==============================] - 115s 462ms/step - loss: 0.9268 - dice_coef_multilabel: 0.6281 - mean_io_u: 0.4168 - accuracy: 0.7728 - val_loss: 0.9246 - val_dice_coef_multilabel: 0.6305 - val_mean_io_u: 0.4167 - val_accuracy: 0.7635
# Epoch 44/65
# 248/248 [==============================] - 116s 469ms/step - loss: 0.9245 - dice_coef_multilabel: 0.6310 - mean_io_u: 0.4168 - accuracy: 0.7722 - val_loss: 0.9220 - val_dice_coef_multilabel: 0.6288 - val_mean_io_u: 0.4167 - val_accuracy: 0.7639
# Epoch 45/65
# 248/248 [==============================] - 115s 462ms/step - loss: 0.9212 - dice_coef_multilabel: 0.6325 - mean_io_u: 0.4168 - accuracy: 0.7729 - val_loss: 0.9204 - val_dice_coef_multilabel: 0.6285 - val_mean_io_u: 0.4167 - val_accuracy: 0.7634
# Epoch 46/65
# 248/248 [==============================] - 117s 471ms/step - loss: 0.9180 - dice_coef_multilabel: 0.6343 - mean_io_u: 0.4168 - accuracy: 0.7735 - val_loss: 0.9218 - val_dice_coef_multilabel: 0.6239 - val_mean_io_u: 0.4167 - val_accuracy: 0.7599
# Epoch 47/65
# 248/248 [==============================] - 115s 462ms/step - loss: 0.9179 - dice_coef_multilabel: 0.6315 - mean_io_u: 0.4168 - accuracy: 0.7749 - val_loss: 0.9182 - val_dice_coef_multilabel: 0.6312 - val_mean_io_u: 0.4167 - val_accuracy: 0.7618
# Epoch 48/65
# 248/248 [==============================] - 117s 474ms/step - loss: 0.9142 - dice_coef_multilabel: 0.6359 - mean_io_u: 0.4169 - accuracy: 0.7742 - val_loss: 0.9174 - val_dice_coef_multilabel: 0.6273 - val_mean_io_u: 0.4167 - val_accuracy: 0.7633
# Epoch 49/65
# 248/248 [==============================] - 115s 463ms/step - loss: 0.9117 - dice_coef_multilabel: 0.6342 - mean_io_u: 0.4169 - accuracy: 0.7755 - val_loss: 0.9138 - val_dice_coef_multilabel: 0.6309 - val_mean_io_u: 0.4167 - val_accuracy: 0.7665
# Epoch 50/65
# 248/248 [==============================] - 117s 472ms/step - loss: 0.9096 - dice_coef_multilabel: 0.6350 - mean_io_u: 0.4169 - accuracy: 0.7761 - val_loss: 0.9152 - val_dice_coef_multilabel: 0.6281 - val_mean_io_u: 0.4167 - val_accuracy: 0.7605
# Epoch 51/65
# 248/248 [==============================] - 114s 461ms/step - loss: 0.9087 - dice_coef_multilabel: 0.6339 - mean_io_u: 0.4168 - accuracy: 0.7769 - val_loss: 0.9113 - val_dice_coef_multilabel: 0.6325 - val_mean_io_u: 0.4167 - val_accuracy: 0.7641
# Epoch 52/65
# 248/248 [==============================] - 116s 470ms/step - loss: 0.9049 - dice_coef_multilabel: 0.6373 - mean_io_u: 0.4169 - accuracy: 0.7775 - val_loss: 0.9103 - val_dice_coef_multilabel: 0.6301 - val_mean_io_u: 0.4167 - val_accuracy: 0.7678
# Epoch 53/65
# 248/248 [==============================] - 114s 460ms/step - loss: 0.9029 - dice_coef_multilabel: 0.6365 - mean_io_u: 0.4168 - accuracy: 0.7777 - val_loss: 0.9072 - val_dice_coef_multilabel: 0.6363 - val_mean_io_u: 0.4167 - val_accuracy: 0.7656
# Epoch 54/65
# 248/248 [==============================] - 121s 489ms/step - loss: 0.9008 - dice_coef_multilabel: 0.6391 - mean_io_u: 0.4169 - accuracy: 0.7778 - val_loss: 0.9072 - val_dice_coef_multilabel: 0.6306 - val_mean_io_u: 0.4167 - val_accuracy: 0.7672
# Epoch 55/65
# 248/248 [==============================] - 114s 461ms/step - loss: 0.8984 - dice_coef_multilabel: 0.6380 - mean_io_u: 0.4169 - accuracy: 0.7794 - val_loss: 0.9066 - val_dice_coef_multilabel: 0.6348 - val_mean_io_u: 0.4167 - val_accuracy: 0.7667
# Epoch 56/65
# 248/248 [==============================] - 114s 459ms/step - loss: 0.8973 - dice_coef_multilabel: 0.6394 - mean_io_u: 0.4168 - accuracy: 0.7782 - val_loss: 0.9048 - val_dice_coef_multilabel: 0.6393 - val_mean_io_u: 0.4167 - val_accuracy: 0.7707
# Epoch 57/65
# 248/248 [==============================] - 114s 459ms/step - loss: 0.8942 - dice_coef_multilabel: 0.6405 - mean_io_u: 0.4169 - accuracy: 0.7797 - val_loss: 0.9041 - val_dice_coef_multilabel: 0.6305 - val_mean_io_u: 0.4167 - val_accuracy: 0.7686
# Epoch 58/65
# 248/248 [==============================] - 114s 460ms/step - loss: 0.8938 - dice_coef_multilabel: 0.6397 - mean_io_u: 0.4169 - accuracy: 0.7811 - val_loss: 0.9025 - val_dice_coef_multilabel: 0.6411 - val_mean_io_u: 0.4167 - val_accuracy: 0.7673
# Epoch 59/65
# 248/248 [==============================] - 115s 462ms/step - loss: 0.8909 - dice_coef_multilabel: 0.6425 - mean_io_u: 0.4170 - accuracy: 0.7812 - val_loss: 0.9030 - val_dice_coef_multilabel: 0.6290 - val_mean_io_u: 0.4167 - val_accuracy: 0.7648
# Epoch 60/65
# 248/248 [==============================] - 115s 463ms/step - loss: 0.8909 - dice_coef_multilabel: 0.6400 - mean_io_u: 0.4169 - accuracy: 0.7811 - val_loss: 0.9002 - val_dice_coef_multilabel: 0.6411 - val_mean_io_u: 0.4167 - val_accuracy: 0.7675
# Epoch 61/65
# 248/248 [==============================] - 114s 460ms/step - loss: 0.8862 - dice_coef_multilabel: 0.6437 - mean_io_u: 0.4170 - accuracy: 0.7834 - val_loss: 0.9011 - val_dice_coef_multilabel: 0.6308 - val_mean_io_u: 0.4167 - val_accuracy: 0.7647
# Epoch 62/65
# 248/248 [==============================] - 114s 461ms/step - loss: 0.8857 - dice_coef_multilabel: 0.6405 - mean_io_u: 0.4169 - accuracy: 0.7820 - val_loss: 0.8983 - val_dice_coef_multilabel: 0.6435 - val_mean_io_u: 0.4167 - val_accuracy: 0.7676
# Epoch 63/65
# 248/248 [==============================] - 114s 461ms/step - loss: 0.8821 - dice_coef_multilabel: 0.6450 - mean_io_u: 0.4170 - accuracy: 0.7836 - val_loss: 0.8984 - val_dice_coef_multilabel: 0.6328 - val_mean_io_u: 0.4167 - val_accuracy: 0.7669
# Epoch 64/65
# 248/248 [==============================] - 116s 469ms/step - loss: 0.8838 - dice_coef_multilabel: 0.6423 - mean_io_u: 0.4169 - accuracy: 0.7839 - val_loss: 0.8977 - val_dice_coef_multilabel: 0.6446 - val_mean_io_u: 0.4167 - val_accuracy: 0.7680
# Epoch 65/65
# 248/248 [==============================] - 117s 470ms/step - loss: 0.8810 - dice_coef_multilabel: 0.6462 - mean_io_u: 0.4170 - accuracy: 0.7849 - val_loss: 0.8948 - val_dice_coef_multilabel: 0.6375 - val_mean_io_u: 0.4167 - val_accuracy: 0.7721

# %%
model.save(f'/content/drive/MyDrive/RSNA_Abdominal_Trauma_Segmentations/Models/UnetV_65_epochs.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
def training_plot(metrics, history):
    f, ax = plt.subplots(1, len(metrics), figsize=(5*len(metrics), 4))
    for idx, metric in enumerate(metrics):
        ax[idx].plot(history.history[metric], ls='dashed')
        ax[idx].set_xlabel("Epochs")
        ax[idx].set_ylabel(metric)
        ax[idx].plot(history.history['val_' + metric]);
        ax[idx].legend([metric, 'val_' + metric])

# %%
training_plot(["loss", "dice_coef_multilabel", "mean_io_u", "accuracy"], history)

# %% [markdown]
# # Evaluation

# %%
from tensorflow.keras.models import load_model

Unet = load_model('/content/drive/MyDrive/RSNA_Abdominal_Trauma_Segmentations/Models/UnetV_65_epochs.h5', custom_objects={'lossFunc': weightedLoss, 'dice_coef_multilabel': dice_coef_multilabel})

# %%
class_weights = [0.17649986,  7.78453571, 41.53978194, 65.20657672, 96.75504125,  6.40743063]
Unet.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss=weightedLoss(tf.keras.losses.categorical_crossentropy, class_weights), metrics=[dice_coef_multilabel, tf.keras.metrics.MeanIoU(num_classes=6), "accuracy"])

# %%
with open(f'/content/drive/MyDrive/RSNA_Abdominal_Trauma_Segmentations/Data/Validation_data/X_y_65504_55928_.npy', 'rb') as f:
        X_val = np.load(f, allow_pickle = True)
        y_val = np.load(f, allow_pickle = True)

# %%
train_masks_cat = to_categorical(y_val, num_classes=6)
y_train_cat = train_masks_cat.reshape((y_val.shape[0], y_val.shape[1], y_val.shape[2], 6))

# %%
# Evaluation on unseen data

evaluation = Unet.evaluate(X_val, y_train_cat)
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/structured_function.py:265: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
# 22/22 [==============================] - 15s 183ms/step - loss: 1.0511 - dice_coef_multilabel: 0.5869 - mean_io_u: 0.4167 - accuracy: 0.7007

# %%
y_pred=Unet.predict(X_val)
y_pred_argmax=np.argmax(y_pred, axis=3)
# Out:
#  2/22 [=>............................] - ETA: 1s
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/structured_function.py:265: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
# 22/22 [==============================] - 2s 71ms/step

# %%
y_pred_argmax=np.argmax(y_pred, axis=3)
y_pred_argmax.shape
# Out:
# (688, 128, 128)

# %%
index = 680

fig, axes = plt.subplots(1, 2, figsize=(10, 4))

axes[0].imshow(y_val[index,:,:], cmap='gray')
axes[0].set_title('Ground truth')

axes[1].imshow(y_pred_argmax[index,:,:], cmap='gray')
axes[1].set_title('Prediction')

plt.tight_layout()

# Show the plot
plt.show()
