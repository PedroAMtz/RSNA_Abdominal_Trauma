# %%
import pandas as pd

# %%
window_data = pd.read_csv("Ventanas.csv")
window_data.head(10)
# Out:
#         ID   Serie_ct V_abdomen Unnamed: 3 V_higado* Unnamed: 5 V_bazo*  \
# 0      NaN        NaN        WL         WW        WL         WW      WL
# 1  10249.0    venoso        107        557       124        139     107
# 2  10249.0  arterial        100        527       100        527     NaN
# 3  10917.0  arterial         57        409        71        157      57
# 4  10917.0     venoso       158        693       131        298     148
# 5  17185.0  arterial         58        434       NaN        NaN     NaN
# 6  17185.0     venoso       135        578       106        206     135
# 7  26598.0     venoso       144        528       173        225     144
# 8  30204.0   arterial        50        400       NaN        NaN     NaN
# 9  30204.0     venoso        50        400        57        152      88
#
#   Unnamed: 7 V_Riñones Unnamed: 9 V_pancreas Unnamed: 11 V_estomago  \
# 0         WW        WL         WW         WL          WW         WL
# ...

# %%
window_data.columns = ['ID', 'Serie_ct', 'V_abdomen WL', 'V_abdomen WW', 'V_higado WL', 'V_higado WW',
       'V_bazo WL', 'V_bazo WW', 'V_Riñones WL', 'V_Riñones WW', 'V_pancreas WL',
       'V_pancreas WW', 'V_estomago WL', 'V_estomago WW', 'fx cadera WL',
       'fx cadera WW']

# %%
window_data.drop(0, inplace=True)

# %%
window_data.reset_index(drop=True, inplace=True)

# %%
window_data
# Out:
#          ID   Serie_ct V_abdomen WL V_abdomen WW V_higado WL V_higado WW  \
# 0   10249.0    venoso           107          557         124         139
# 1   10249.0  arterial           100          527         100         527
# 2   10917.0  arterial            57          409          71         157
# 3   10917.0     venoso          158          693         131         298
# 4   17185.0  arterial            58          434         NaN         NaN
# 5   17185.0     venoso          135          578         106         206
# 6   26598.0     venoso          144          528         173         225
# 7   30204.0   arterial           50          400         NaN         NaN
# 8   30204.0     venoso           50          400          57         152
# 9   53620.0  arterial            63          440         NaN         NaN
# 10  17978.0    venoso           188          821         178         359
# 11  55888.0   arterial          112          538          99         216
#
# ...

# %%
window_data.to_csv("Windows_cleaned")
